# %% [markdown]
# **Instructions**
# 1. Create a set of 2,000 random latitudes and longitudes
# 2. Get nearest city using citipy
# 3. Perform an API call with the OpenWeatherMap
# 4. Retrieve the following from the API call:
#     - Latitude and longitude
#     - maximum temperature
#     - percent humidity
#     - percent cloudiness
#     - wind speed
#     - weather description
# 5. Add Data to a new DataFrame
# 6. Export DataFrame as a CSV file and save it as "WeatherPy_Database.csv" in the Weather_Database folder

# %%
# import modules, dependencies, and API key
from citipy import citipy
import numpy as np
import pandas as pd
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of 2,000 random latitudes and longitudes
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-90, 90, size=2000)

# pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# unpack latitudes and longitudes into a list
coordinates = list(lat_lngs)

# %%
# Create a list for the cities
cities = []
# Get nearest cities
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
        # Parse the JSON and retrieve data.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Country": city_country})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | garmsar
# Processing Record 2 of Set 1 | kruisfontein
# Processing Record 3 of Set 1 | tucuma
# Processing Record 4 of Set 1 | nicoya
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 9 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 1 | westport
# Processing Record 11 of Set 1 | dromolaxia
# Processing Record 12 of Set 1 | mikhaylovsk
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | wum
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | dwarka
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 1 | talah
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Garmsar  35.2182  52.3409     52.30        29           0        4.07
# 1  Kruisfontein -34.0033  24.7314     60.89        95          98        5.41
# 2        Tucuma  -0.1833 -50.0500     73.69        96         100        3.24
# 3        Nicoya  10.1483 -85.4520     83.55        58         100        6.96
# 4  Ponta Do Sol  32.6667 -17.1000     64.00        70          58        5.41
# 5  Longyearbyen  78.2186  15.6401     10.24        72           0        8.05
# 6      Tasiilaq  65.6145 -37.6368     26.76        76         100       11.99
# 7      Westport  41.1415 -73.3579     35.56        35           0       10.36
# 8    Dromolaxia  34.8761  33.5860     61.99        58           0        8.05
# 9   Mikhaylovsk  45.1283  42.0256     48.42        40           0        8.99
#
#   Current Description Country
# 0           clear sky      IR
# 1     overcast clouds      ZA
# ...

# %%
new_column_order = ["City","Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       Garmsar      IR  35.2182  52.3409     52.30        29           0
# 1  Kruisfontein      ZA -34.0033  24.7314     60.89        95          98
# 2        Tucuma      BR  -0.1833 -50.0500     73.69        96         100
# 3        Nicoya      CR  10.1483 -85.4520     83.55        58         100
# 4  Ponta Do Sol      PT  32.6667 -17.1000     64.00        70          58
#
#    Wind Speed Current Description
# 0        4.07           clear sky
# 1        5.41     overcast clouds
# 2        3.24       moderate rain
# 3        6.96     overcast clouds
# 4        5.41       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
